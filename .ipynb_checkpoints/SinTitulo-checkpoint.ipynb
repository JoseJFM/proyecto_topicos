# %% [markdown]
# # Proyecto Venta de Videojuegos
# ## Topicos Avanzados de Ciencias de la Computacion
#
# Este proyecto pretende demostrar un control básico sobre un DataFrame utilizando pandas. También se quiere mostrar un manejo sencillo sobre librerías como WordCloud y PyPlot.

# %% [markdown]
# Para iniciar, Importamos todo lo necesario para hacer que esto funcione...

# %%
import pandas as pd
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt

# %% [markdown]
# ### Estableciendo y manipulando un DataFrame

# %% [markdown]
# Con lo siguiente lograremos, utilizando pandas, recopilar la información contenida dentro de nuestro .csv, para crear así un DataFrame.

# %%
df = pd.read_csv('datasets/vgsales.csv')

# %% [markdown]
# Ahora nos desharemos de todos los renglones que no contengan datos

# %%
df = df.dropna()

# %% [markdown]
# y mostraremos el contenido de nuestro DataFrame... pero solamente los primeros 10 renglones.

# %%
df.head(10)
#Y son muchos
# Out:
#    Rank                       Name Platform    Year         Genre Publisher  \
# 0     1                 Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2          Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3             Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4          Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5   Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
# 5     6                     Tetris       GB  1989.0        Puzzle  Nintendo
# 6     7      New Super Mario Bros.       DS  2006.0      Platform  Nintendo
# 7     8                   Wii Play      Wii  2006.0          Misc  Nintendo
# 8     9  New Super Mario Bros. Wii      Wii  2009.0      Platform  Nintendo
# 9    10                  Duck Hunt      NES  1984.0       Shooter  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37
# 5     23.20      2.26      4.22         0.58         30.26
# 6     11.38      9.23      6.50         2.90         30.01
# 7     14.03      9.20      2.93         2.85         29.02
# 8     14.59      7.06      4.70         2.26         28.62
# 9     26.93      0.63      0.28         0.47         28.31

# %% [markdown]
# Ya que está nuestro DataFrame cargado, podemos seleccionar una columna a nuestra preferencia y declarar los datos únicos contenidos en la misma, en este caso "publisher".

# %%
publishers = df["Publisher"].unique()

# %%
publishers
# Out:
# array(['Nintendo', 'Microsoft Game Studios', 'Take-Two Interactive',
#        'Sony Computer Entertainment', 'Activision', 'Ubisoft',
#        'Bethesda Softworks', 'Electronic Arts', 'Sega', 'SquareSoft',
#        'Atari', '505 Games', 'Capcom', 'GT Interactive',
#        'Konami Digital Entertainment',
#        'Sony Computer Entertainment Europe', 'Square Enix', 'LucasArts',
#        'Virgin Interactive', 'Warner Bros. Interactive Entertainment',
#        'Universal Interactive', 'Eidos Interactive', 'RedOctane',
#        'Vivendi Games', 'Enix Corporation', 'Namco Bandai Games',
#        'Palcom', 'Hasbro Interactive', 'THQ', 'Fox Interactive',
#        'Acclaim Entertainment', 'MTV Games', 'Disney Interactive Studios',
#        'Majesco Entertainment', 'Codemasters', 'Red Orb', 'Level 5',
#        'Arena Entertainment', 'Midway Games', 'JVC', 'Deep Silver',
#        '989 Studios', 'NCSoft', 'UEP Systems', 'Parker Bros.', 'Maxis',
#        'Imagic', 'Tecmo Koei', 'Valve Software', 'ASCII Entertainment',
#        'Mindscape', 'Infogrames', 'Unknown', 'Square', 'Valve',
#        'Activision Value', 'Banpresto', 'D3Publisher',
#        'Oxygen Interactive', 'Red Storm Entertainment', 'Video System',
#        'Hello Games', 'Global Star', 'Gotham Games', 'Westwood Studios',
#        'GungHo', 'Crave Entertainment', 'Hudson Soft', 'Coleco',
#        'Rising Star Games', 'Atlus', 'TDK Mediactive', 'ASC Games',
#        'Zoo Games', 'Accolade', 'Sony Online Entertainment', '3DO', 'RTL',
#        'Natsume', 'Focus Home Interactive', 'Alchemist',
#        'Black Label Games', 'SouthPeak Games', 'Mastertronic', 'Ocean',
#        'Zoo Digital Publishing', 'Psygnosis', 'City Interactive',
#        'Empire Interactive', 'Success', 'Compile', 'Russel', 'Taito',
#        'Agetec', 'GSP', 'Microprose', 'Play It', 'Slightly Mad Studios',
#        'Tomy Corporation', 'Sammy Corporation', 'Koch Media',
#        'Game Factory', 'Titus', 'Marvelous Entertainment', 'Genki',
#        'Mojang', 'Pinnacle', 'CTO SpA', 'TalonSoft', 'Crystal Dynamics',
#        'SCi', 'Quelle', 'mixi, Inc', 'Rage Software', 'Ubisoft Annecy',
#        'Scholastic Inc.', 'Interplay', 'Mystique', 'ChunSoft',
#        'Square EA', '20th Century Fox Video Games', 'Avanquest Software',
#        'Hudson Entertainment', 'Nordic Games', 'Men-A-Vision', 'Nobilis',
#        'Big Ben Interactive', 'Touchstone', 'Spike', 'Jester Interactive',
#        'Nippon Ichi Software', 'LEGO Media', 'Quest',
#        'Illusion Softworks', 'Tigervision', 'Funbox Media',
#        'Rocket Company', 'Metro 3D', 'Mattel Interactive', 'IE Institute',
#        'Rondomedia', 'Sony Computer Entertainment America',
#        'Universal Gamex', 'Ghostlight', 'Wizard Video Games',
#        'BMG Interactive Entertainment', 'PQube', 'Trion Worlds', 'Laguna',
#        'Ignition Entertainment', 'Takara', 'Kadokawa Shoten', 'Destineer',
#        'Enterbrain', 'Xseed Games', 'Imagineer',
#        'System 3 Arcade Software', 'CPG Products', 'Aruze Corp',
#        'Gamebridge', 'Midas Interactive Entertainment', 'Jaleco',
#        'Answer Software', 'XS Games', 'Activision Blizzard',
#        'Pack In Soft', 'Rebellion', 'Xplosiv', 'GameMill Entertainment',
#        'Wanadoo', 'NovaLogic', 'Telltale Games', 'Epoch',
#        'BAM! Entertainment', 'Knowledge Adventure', 'Mastiff',
#        'Tetris Online', 'Harmonix Music Systems', 'ESP', 'TYO',
#        'Telegames', 'Mud Duck Productions', 'Screenlife', 'Pioneer LDC',
#        'Magical Company', 'Mentor Interactive', 'Kemco',
#        'Human Entertainment', 'Avanquest', 'Data Age',
#        'Electronic Arts Victor', 'Black Bean Games', 'Jack of All Games',
#        '989 Sports', 'Takara Tomy', 'Media Rings', 'Elf', 'Starfish',
#        'Zushi Games', 'Jorudan', 'Destination Software, Inc', 'New',
#        'Brash Entertainment', 'ITT Family Games', 'PopCap Games',
#        'Home Entertainment Suppliers', 'Ackkstudios', 'Starpath Corp.',
#        'P2 Games', 'BPS', 'Gathering of Developers', 'NewKidCo',
#        'Storm City Games', 'CokeM Interactive', 'CBS Electronics',
#        'Magix', 'Marvelous Interactive', 'Kalypso Media',
#        'Nihon Falcom Corporation', 'Wargaming.net', 'Angel Studios',
#        'Arc System Works', 'Playmates', 'SNK Playmore',
#        'Hamster Corporation', 'From Software', 'Nippon Columbia',
#        'Nichibutsu', 'Little Orbit', 'Conspiracy Entertainment',
#        'DTP Entertainment', 'Hect', 'Mumbo Jumbo',
#        'Pacific Century Cyber Works', 'Indie Games', 'Liquid Games',
#        'NEC', 'Axela', 'ArtDink', 'Sunsoft', 'Gust', 'SNK',
#        'NEC Interchannel', 'FuRyu', 'Xing Entertainment', 'ValuSoft',
#        'Victor Interactive', 'Detn8 Games', 'American Softworks',
#        'Nordcurrent', 'Bomb', 'Falcom Corporation', 'AQ Interactive',
#        'CCP', 'Milestone S.r.l.', 'JoWood Productions',
#        'Seta Corporation', 'On Demand', 'NCS', 'Aspyr',
#        'Gremlin Interactive Ltd', 'Agatsuma Entertainment',
#        'Compile Heart', 'Culture Brain', 'Mad Catz', 'Shogakukan',
#        'Merscom LLC', 'Rebellion Developments', 'Nippon Telenet',
#        'TDK Core', 'bitComposer Games', 'Foreign Media Games', 'Astragon',
#        'SSI', 'Kadokawa Games', 'Idea Factory',
#        'Performance Designed Products', 'Asylum Entertainment',
#        'Core Design Ltd.', 'PlayV', 'UFO Interactive',
#        'Idea Factory International', 'Playlogic Game Factory',
#        'Essential Games', 'Adeline Software', 'Funcom',
#        'Panther Software', 'Blast! Entertainment Ltd', 'Game Life',
#        'DSI Games', 'Avalon Interactive', 'Popcorn Arcade',
#        'Neko Entertainment', 'Vir2L Studios', 'Aques', 'Syscom',
#        'White Park Bay Software', 'System 3', 'Vatical Entertainment',
#        'Daedalic', 'EA Games', 'Media Factory', 'Vic Tokai',
#        'The Adventure Company', 'Game Arts', 'Broccoli', 'Acquire',
#        'General Entertainment', 'Excalibur Publishing', 'Imadio',
#        'Swing! Entertainment', 'Sony Music Entertainment', 'Aqua Plus',
#        'Paradox Interactive', 'Hip Interactive',
#        'DreamCatcher Interactive', 'Tripwire Interactive', 'Sting',
#        'Yacht Club Games', 'SCS Software', 'Bigben Interactive',
#        'Havas Interactive', 'Slitherine Software', 'Graffiti', 'Funsta',
#        'Telstar', 'U.S. Gold', 'DreamWorks Interactive',
#        'Data Design Interactive', 'MTO', 'DHM Interactive', 'FunSoft',
#        'SPS', 'Bohemia Interactive', 'Reef Entertainment',
#        'Tru Blu Entertainment', 'Moss', 'T&E Soft', 'O-Games',
#        'Aksys Games', 'NDA Productions', 'Data East',
#        'Time Warner Interactive', 'Gainax Network Systems', 'Daito',
#        'O3 Entertainment', 'Gameloft', 'Xicat Interactive',
#        'Simon & Schuster Interactive', 'Valcon Games', 'PopTop Software',
#        'TOHO', 'HMH Interactive', '5pb', 'Cave',
#        'CDV Software Entertainment', 'Microids', 'PM Studios', 'Paon',
#        'Micro Cabin', 'GameTek', 'Benesse', 'Type-Moon',
#        'Enjoy Gaming ltd.', 'Asmik Corp', 'Interplay Productions',
#        'Asmik Ace Entertainment', 'inXile Entertainment', 'Image Epoch',
#        'Phantom EFX', 'Evolved Games', 'responDESIGN',
#        'Culture Publishers', 'Griffin International', 'Hackberry',
#        'Hearty Robin', 'Nippon Amuse', 'Origin Systems', 'Seventh Chord',
#        'Mitsui', 'Milestone', 'Abylight', 'Flight-Plan', 'Glams', 'Locus',
#        'Warp', 'Daedalic Entertainment', 'Alternative Software',
#        'Myelin Media', 'Mercury Games', 'Irem Software Engineering',
#        'Sunrise Interactive', 'Elite', 'Evolution Games', 'Tivola',
#        'Global A Entertainment', 'Edia', 'Athena', 'Aria', 'Gamecock',
#        'Tommo', 'Altron', 'Happinet', 'iWin', 'Media Works', 'Fortyfive',
#        'Revolution Software', 'Imax', 'Crimson Cow', '10TACLE Studios',
#        'Groove Games', 'Pack-In-Video', 'Insomniac Games',
#        'Ascaron Entertainment GmbH', 'Asgard', 'Ecole', 'Yumedia',
#        'Phenomedia', 'HAL Laboratory', 'Grand Prix Games', 'DigiCube',
#        'Creative Core', 'Kaga Create', 'WayForward Technologies',
#        'LSP Games', 'ASCII Media Works', 'Coconuts Japan', 'Arika',
#        'Ertain', 'Marvel Entertainment', 'Prototype', 'Phantagram',
#        '1C Company', 'The Learning Company', 'TechnoSoft', 'Vap',
#        'Misawa', 'Tradewest', 'Team17 Software', 'Yeti', 'Pow',
#        'Navarre Corp', 'MediaQuest', 'Max Five', 'Comfort',
#        'Monte Christo Multimedia', 'Pony Canyon', 'Riverhillsoft',
#        'Summitsoft', 'Milestone S.r.l', 'Playmore', 'MLB.com',
#        'Kool Kizz', 'Flashpoint Games', '49Games', 'Legacy Interactive',
#        'Alawar Entertainment', 'CyberFront',
#        'Cloud Imperium Games Corporation', 'Societa',
#        'Virtual Play Games', 'Interchannel', 'Sonnet', 'Experience Inc.',
#        'Zenrin', 'Iceberg Interactive', 'Ivolgamus', '2D Boy',
#        'MC2 Entertainment', 'Kando Games', 'Just Flight', 'Office Create',
#        'Mamba Games', 'Fields', 'Princess Soft', 'Maximum Family Games',
#        'Berkeley', 'Fuji', 'Dusenberry Martin Racing', 'imageepoch Inc.',
#        'Big Fish Games', 'Her Interactive', 'Kamui', 'ASK',
#        'TopWare Interactive', 'Headup Games', 'KSS', 'Cygames', 'KID',
#        'Quinrose', 'Sunflowers', 'dramatic create', 'TGL', 'Encore',
#        'Extreme Entertainment Group', 'Intergrow', 'G.Rev', 'Sweets',
#        'Kokopeli Digital Studios', 'Number None', 'Nexon', 'id Software',
#        'BushiRoad', 'Tryfirst', 'Strategy First', '7G//AMES',
#        'GN Software', "Yuke's", 'Easy Interactive', 'Licensed 4U',
#        'FuRyu Corporation', 'Lexicon Entertainment', 'Paon Corporation',
#        'Kids Station', 'GOA', 'Graphsim Entertainment', 'King Records',
#        'Introversion Software', 'Minato Station', 'Devolver Digital',
#        'Blue Byte', 'Gaga', 'Yamasa Entertainment', 'Plenty', 'Views',
#        'fonfun', 'NetRevo', 'Codemasters Online', 'Quintet',
#        'Phoenix Games', 'Dorart', 'Marvelous Games', 'Focus Multimedia',
#        'Imageworks', 'Karin Entertainment', 'Aerosoft',
#        'Technos Japan Corporation', 'Gakken', 'Mirai Shounen',
#        'Datam Polystar', 'Saurus', 'HuneX', 'Revolution (Japan)',
#        'Giza10', 'Visco', 'Alvion', 'Mycom', 'Giga', 'Warashi',
#        'System Soft', 'Sold Out', 'Lighthouse Interactive',
#        'Masque Publishing', 'RED Entertainment', 'Michaelsoft',
#        'Media Entertainment', 'New World Computing', 'Genterprise',
#        'Interworks Unlimited, Inc.', 'Boost On', 'Stainless Games',
#        'EON Digital Entertainment', 'Epic Games', 'Naxat Soft',
#        'Ascaron Entertainment', 'Piacci', 'Nitroplus',
#        'Paradox Development', 'Otomate', 'Ongakukan', 'Commseed',
#        'Inti Creates', 'Takuyo', 'Interchannel-Holon', 'Rain Games',
#        'UIG Entertainment'], dtype=object)

# %% [markdown]
# Ahora declaramos las columnas más relevantes de nuestro DataFrame.

# %%
df_overall = df[['Name','Year', 'Publisher', 'Platform',  'Global_Sales']]

# %% [markdown]
# Y si queremos el dato más repetido (moda) en una columna?

# %%
df_overall["Platform"].mode()
# Out:
# 0    DS
# dtype: object

# %% [markdown]
# Qué tal si queremos la información, correspondiente a uno de esos datos únicos dentro de la columna, de dentro de nuestro DataFrame?... Por ahora solo mostremos 10.

# %%
booleans = df_overall['Publisher'] == 'Electronic Arts' #<--- Incruste aqui uno de los datos
df_publisher = df_overall[booleans]
df_publisher.head(10)
#son muuuuchos más...
# Out:
#                              Name    Year        Publisher Platform  \
# 77                        FIFA 16  2015.0  Electronic Arts      PS4
# 82                 FIFA Soccer 13  2012.0  Electronic Arts      PS3
# 83                     The Sims 3  2009.0  Electronic Arts       PC
# 92   Star Wars Battlefront (2015)  2015.0  Electronic Arts      PS4
# 99                  Battlefield 3  2011.0  Electronic Arts     X360
# 103                 Battlefield 3  2011.0  Electronic Arts      PS3
# 104    Need for Speed Underground  2003.0  Electronic Arts      PS2
# 112                       FIFA 14  2013.0  Electronic Arts      PS3
# 113  Need for Speed Underground 2  2004.0  Electronic Arts      PS2
# 114     Medal of Honor: Frontline  2002.0  Electronic Arts      PS2
#
#      Global_Sales
# 77           8.49
# 82           8.24
# 83           8.11
# 92           7.67
# 99           7.34
# 103          7.23
# 104          7.20
# 112          6.90
# 113          6.90
# 114          6.83

# %% [markdown]
# Con lo siguiente podremos observar el promedio numérico (Global_Sales) para uno y cada uno de nuestros datos únicos (Publisher), anteriormente obtenidos.

# %%
def calculate_global_sale_average(publisher):
    booleans = df_overall['Publisher'] == publisher
    df_publisher = df_overall[booleans]
    print('Venta global promedio de un juego de <<', publisher, '>> es:', df_publisher['Global_Sales'].sum() / len(df_publisher))

# %%
calculate_global_sale_average('Nintendo')
# Out:
# Venta global promedio de un juego de << Nintendo >> es: 2.563836206896552

# %%
for publisher in publishers:
    calculate_global_sale_average(publisher)
# Out:
# Venta global promedio de un juego de << Nintendo >> es: 2.563836206896552
# Venta global promedio de un juego de << Microsoft Game Studios >> es: 1.3004761904761906
# Venta global promedio de un juego de << Take-Two Interactive >> es: 0.9691747572815534
# Venta global promedio de un juego de << Sony Computer Entertainment >> es: 0.8904398826979474
# Venta global promedio de un juego de << Activision >> es: 0.7468012422360248
# Venta global promedio de un juego de << Ubisoft >> es: 0.515838779956427
# Venta global promedio de un juego de << Bethesda Softworks >> es: 1.1815942028985504
# Venta global promedio de un juego de << Electronic Arts >> es: 0.8165720687079911
# Venta global promedio de un juego de << Sega >> es: 0.4283227848101266
# Venta global promedio de un juego de << SquareSoft >> es: 1.1086538461538462
# Venta global promedio de un juego de << Atari >> es: 0.4229682997118155
# Venta global promedio de un juego de << 505 Games >> es: 0.29119791666666667
# Venta global promedio de un juego de << Capcom >> es: 0.531781914893617
# Venta global promedio de un juego de << GT Interactive >> es: 0.5606666666666666
# Venta global promedio de un juego de << Konami Digital Entertainment >> es: 0.3384690157958688
# Venta global promedio de un juego de << Sony Computer Entertainment Europe >> es: 1.592666666666667
# Venta global promedio de un juego de << Square Enix >> es: 0.6265367965367966
# Venta global promedio de un juego de << LucasArts >> es: 0.9544943820224719
# Venta global promedio de un juego de << Virgin Interactive >> es: 0.7075806451612905
# Venta global promedio de un juego de << Warner Bros. Interactive Entertainment >> es: 0.6559447004608295
# Venta global promedio de un juego de << Universal Interactive >> es: 0.8
# Venta global promedio de un juego de << Eidos Interactive >> es: 0.49362244897959184
# Venta global promedio de un juego de << RedOctane >> es: 2.17
# Venta global promedio de un juego de << Vivendi Games >> es: 0.35360248447204967
# Venta global promedio de un juego de << Enix Corporation >> es: 1.1246666666666665
# Venta global promedio de un juego de << Namco Bandai Games >> es: 0.2733297413793104
# Venta global promedio de un juego de << Palcom >> es: 4.17
# Venta global promedio de un juego de << Hasbro Interactive >> es: 0.95125
# Venta global promedio de un juego de << THQ >> es: 0.47814606741573035
# Venta global promedio de un juego de << Fox Interactive >> es: 0.9237499999999998
# Venta global promedio de un juego de << Acclaim Entertainment >> es: 0.34858695652173916
# Venta global promedio de un juego de << MTV Games >> es: 0.4715
# Venta global promedio de un juego de << Disney Interactive Studios >> es: 0.5549532710280374
# Venta global promedio de un juego de << Majesco Entertainment >> es: 0.1756666666666667
# Venta global promedio de un juego de << Codemasters >> es: 0.3184666666666666
# Venta global promedio de un juego de << Red Orb >> es: 2.62
# Venta global promedio de un juego de << Level 5 >> es: 0.4507407407407407
# Venta global promedio de un juego de << Arena Entertainment >> es: 2.36
# Venta global promedio de un juego de << Midway Games >> es: 0.35352040816326535
# Venta global promedio de un juego de << JVC >> es: 0.35000000000000003
# Venta global promedio de un juego de << Deep Silver >> es: 0.21148760330578506
# Venta global promedio de un juego de << 989 Studios >> es: 0.9514285714285713
# Venta global promedio de un juego de << NCSoft >> es: 0.4316666666666666
# Venta global promedio de un juego de << UEP Systems >> es: 2.25
# Venta global promedio de un juego de << Parker Bros. >> es: 0.71
# Venta global promedio de un juego de << Maxis >> es: 1.1300000000000001
# Venta global promedio de un juego de << Imagic >> es: 1.205
# Venta global promedio de un juego de << Tecmo Koei >> es: 0.15843195266272192
# Venta global promedio de un juego de << Valve Software >> es: 1.0766666666666669
# Venta global promedio de un juego de << ASCII Entertainment >> es: 0.5445
# Venta global promedio de un juego de << Mindscape >> es: 0.241875
# Venta global promedio de un juego de << Infogrames >> es: 0.2652459016393443
# Venta global promedio de un juego de << Unknown >> es: 0.1364
# Venta global promedio de un juego de << Square >> es: 0.6066666666666667
# Venta global promedio de un juego de << Valve >> es: 1.74
# Venta global promedio de un juego de << Activision Value >> es: 0.24
# Venta global promedio de un juego de << Banpresto >> es: 0.23835616438356166
# Venta global promedio de un juego de << D3Publisher >> es: 0.13147540983606557
# Venta global promedio de un juego de << Oxygen Interactive >> es: 0.16428571428571428
# Venta global promedio de un juego de << Red Storm Entertainment >> es: 0.7733333333333333
# Venta global promedio de un juego de << Video System >> es: 0.545
# Venta global promedio de un juego de << Hello Games >> es: 1.6
# Venta global promedio de un juego de << Global Star >> es: 0.19615384615384612
# Venta global promedio de un juego de << Gotham Games >> es: 0.5314285714285714
# Venta global promedio de un juego de << Westwood Studios >> es: 1.55
# Venta global promedio de un juego de << GungHo >> es: 0.24230769230769228
# Venta global promedio de un juego de << Crave Entertainment >> es: 0.1398591549295774
# Venta global promedio de un juego de << Hudson Soft >> es: 0.28407407407407403
# Venta global promedio de un juego de << Coleco >> es: 0.6119999999999999
# Venta global promedio de un juego de << Rising Star Games >> es: 0.20317647058823532
# Venta global promedio de un juego de << Atlus >> es: 0.19014925373134325
# Venta global promedio de un juego de << TDK Mediactive >> es: 0.2308333333333333
# Venta global promedio de un juego de << ASC Games >> es: 0.6733333333333333
# Venta global promedio de un juego de << Zoo Games >> es: 0.14606060606060606
# Venta global promedio de un juego de << Accolade >> es: 0.5599999999999999
# Venta global promedio de un juego de << Sony Online Entertainment >> es: 0.44125
# Venta global promedio de un juego de << 3DO >> es: 0.28111111111111103
# Venta global promedio de un juego de << RTL >> es: 0.24999999999999997
# Venta global promedio de un juego de << Natsume >> es: 0.21705882352941175
# Venta global promedio de un juego de << Focus Home Interactive >> es: 0.13285714285714287
# Venta global promedio de un juego de << Alchemist >> es: 0.061162790697674406
# Venta global promedio de un juego de << Black Label Games >> es: 1.2
# Venta global promedio de un juego de << SouthPeak Games >> es: 0.1716216216216216
# Venta global promedio de un juego de << Mastertronic >> es: 0.13307692307692306
# Venta global promedio de un juego de << Ocean >> es: 0.2578571428571429
# Venta global promedio de un juego de << Zoo Digital Publishing >> es: 0.12375000000000001
# Venta global promedio de un juego de << Psygnosis >> es: 0.22718750000000001
# Venta global promedio de un juego de << City Interactive >> es: 0.2544444444444445
# Venta global promedio de un juego de << Empire Interactive >> es: 0.2184313725490196
# Venta global promedio de un juego de << Success >> es: 0.1031578947368421
# Venta global promedio de un juego de << Compile >> es: 0.4099999999999999
# Venta global promedio de un juego de << Russel >> es: 0.2016666666666667
# Venta global promedio de un juego de << Taito >> es: 0.1494736842105263
# Venta global promedio de un juego de << Agetec >> es: 0.2425
# Venta global promedio de un juego de << GSP >> es: 0.23062500000000002
# Venta global promedio de un juego de << Microprose >> es: 0.396
# Venta global promedio de un juego de << Play It >> es: 0.30785714285714283
# Venta global promedio de un juego de << Slightly Mad Studios >> es: 0.46
# Venta global promedio de un juego de << Tomy Corporation >> es: 0.2761111111111111
# Venta global promedio de un juego de << Sammy Corporation >> es: 0.24818181818181817
# Venta global promedio de un juego de << Koch Media >> es: 0.27705882352941175
# Venta global promedio de un juego de << Game Factory >> es: 0.1184375
# Venta global promedio de un juego de << Titus >> es: 0.17473684210526316
# Venta global promedio de un juego de << Marvelous Entertainment >> es: 0.19416666666666663
# Venta global promedio de un juego de << Genki >> es: 0.1825
# Venta global promedio de un juego de << Mojang >> es: 0.5780000000000001
# Venta global promedio de un juego de << Pinnacle >> es: 0.28400000000000003
# Venta global promedio de un juego de << CTO SpA >> es: 0.45
# Venta global promedio de un juego de << TalonSoft >> es: 0.87
# Venta global promedio de un juego de << Crystal Dynamics >> es: 0.34199999999999997
# Venta global promedio de un juego de << SCi >> es: 0.20705882352941177
# Venta global promedio de un juego de << Quelle >> es: 0.87
# Venta global promedio de un juego de << mixi, Inc >> es: 0.86
# Venta global promedio de un juego de << Rage Software >> es: 0.2028571428571429
# Venta global promedio de un juego de << Ubisoft Annecy >> es: 0.31857142857142856
# Venta global promedio de un juego de << Scholastic Inc. >> es: 0.2909999999999999
# Venta global promedio de un juego de << Interplay >> es: 0.22199999999999998
# Venta global promedio de un juego de << Mystique >> es: 0.82
# Venta global promedio de un juego de << ChunSoft >> es: 0.22611111111111107
# Venta global promedio de un juego de << Square EA >> es: 0.8
# Venta global promedio de un juego de << 20th Century Fox Video Games >> es: 0.388
# Venta global promedio de un juego de << Avanquest Software >> es: 0.1877777777777778
# Venta global promedio de un juego de << Hudson Entertainment >> es: 0.15363636363636363
# Venta global promedio de un juego de << Nordic Games >> es: 0.12685714285714284
# Venta global promedio de un juego de << Men-A-Vision >> es: 0.77
# Venta global promedio de un juego de << Nobilis >> es: 0.14923076923076925
# Venta global promedio de un juego de << Big Ben Interactive >> es: 0.14285714285714285
# Venta global promedio de un juego de << Touchstone >> es: 0.3950000000000001
# Venta global promedio de un juego de << Spike >> es: 0.16621621621621624
# Venta global promedio de un juego de << Jester Interactive >> es: 0.3833333333333333
# Venta global promedio de un juego de << Nippon Ichi Software >> es: 0.13442307692307692
# Venta global promedio de un juego de << LEGO Media >> es: 0.22285714285714284
# Venta global promedio de un juego de << Quest >> es: 0.71
# Venta global promedio de un juego de << Illusion Softworks >> es: 0.7
# Venta global promedio de un juego de << Tigervision >> es: 0.47333333333333333
# Venta global promedio de un juego de << Funbox Media >> es: 0.1516666666666667
# Venta global promedio de un juego de << Rocket Company >> es: 0.10705882352941176
# Venta global promedio de un juego de << Metro 3D >> es: 0.15333333333333335
# Venta global promedio de un juego de << Mattel Interactive >> es: 0.2925
# Venta global promedio de un juego de << IE Institute >> es: 0.19200000000000003
# Venta global promedio de un juego de << Rondomedia >> es: 0.1842857142857143
# Venta global promedio de un juego de << Sony Computer Entertainment America >> es: 0.39333333333333337
# Venta global promedio de un juego de << Universal Gamex >> es: 0.63
# Venta global promedio de un juego de << Ghostlight >> es: 0.1907142857142857
# Venta global promedio de un juego de << Wizard Video Games >> es: 0.62
# Venta global promedio de un juego de << BMG Interactive Entertainment >> es: 0.1685714285714286
# Venta global promedio de un juego de << PQube >> es: 0.10948717948717948
# Venta global promedio de un juego de << Trion Worlds >> es: 0.2875
# Venta global promedio de un juego de << Laguna >> es: 0.3875
# Venta global promedio de un juego de << Ignition Entertainment >> es: 0.11288135593220339
# Venta global promedio de un juego de << Takara >> es: 0.215625
# Venta global promedio de un juego de << Kadokawa Shoten >> es: 0.0754
# Venta global promedio de un juego de << Destineer >> es: 0.09688888888888887
# Venta global promedio de un juego de << Enterbrain >> es: 0.14866666666666667
# Venta global promedio de un juego de << Xseed Games >> es: 0.225
# Venta global promedio de un juego de << Imagineer >> es: 0.165625
# Venta global promedio de un juego de << System 3 Arcade Software >> es: 0.13692307692307695
# Venta global promedio de un juego de << CPG Products >> es: 0.54
# Venta global promedio de un juego de << Aruze Corp >> es: 0.39333333333333337
# Venta global promedio de un juego de << Gamebridge >> es: 0.365
# Venta global promedio de un juego de << Midas Interactive Entertainment >> es: 0.11333333333333334
# Venta global promedio de un juego de << Jaleco >> es: 0.08434782608695653
# Venta global promedio de un juego de << Answer Software >> es: 0.5
# Venta global promedio de un juego de << XS Games >> es: 0.12166666666666666
# Venta global promedio de un juego de << Activision Blizzard >> es: 0.48
# Venta global promedio de un juego de << Pack In Soft >> es: 0.48
# Venta global promedio de un juego de << Rebellion >> es: 0.245
# Venta global promedio de un juego de << Xplosiv >> es: 0.164
# Venta global promedio de un juego de << GameMill Entertainment >> es: 0.1725
# Venta global promedio de un juego de << Wanadoo >> es: 0.13000000000000003
# Venta global promedio de un juego de << NovaLogic >> es: 0.2733333333333334
# Venta global promedio de un juego de << Telltale Games >> es: 0.1088
# Venta global promedio de un juego de << Epoch >> es: 0.15
# Venta global promedio de un juego de << BAM! Entertainment >> es: 0.1414285714285714
# Venta global promedio de un juego de << Knowledge Adventure >> es: 0.3675
# Venta global promedio de un juego de << Mastiff >> es: 0.139375
# Venta global promedio de un juego de << Tetris Online >> es: 0.43
# Venta global promedio de un juego de << Harmonix Music Systems >> es: 0.4
# Venta global promedio de un juego de << ESP >> es: 0.11800000000000002
# Venta global promedio de un juego de << TYO >> es: 0.42
# Venta global promedio de un juego de << Telegames >> es: 0.12875
# Venta global promedio de un juego de << Mud Duck Productions >> es: 0.2833333333333333
# Venta global promedio de un juego de << Screenlife >> es: 0.15333333333333332
# Venta global promedio de un juego de << Pioneer LDC >> es: 0.185
# Venta global promedio de un juego de << Magical Company >> es: 0.41
# Venta global promedio de un juego de << Mentor Interactive >> es: 0.21400000000000002
# Venta global promedio de un juego de << Kemco >> es: 0.10571428571428568
# Venta global promedio de un juego de << Human Entertainment >> es: 0.23076923076923078
# Venta global promedio de un juego de << Avanquest >> es: 0.11760000000000001
# Venta global promedio de un juego de << Data Age >> es: 0.355
# Venta global promedio de un juego de << Electronic Arts Victor >> es: 0.21
# Venta global promedio de un juego de << Black Bean Games >> es: 0.09566666666666665
# Venta global promedio de un juego de << Jack of All Games >> es: 0.14
# Venta global promedio de un juego de << 989 Sports >> es: 0.38
# Venta global promedio de un juego de << Takara Tomy >> es: 0.07297297297297295
# Venta global promedio de un juego de << Media Rings >> es: 0.21666666666666667
# Venta global promedio de un juego de << Elf >> es: 0.32
# Venta global promedio de un juego de << Starfish >> es: 0.072
# Venta global promedio de un juego de << Zushi Games >> es: 0.105
# Venta global promedio de un juego de << Jorudan >> es: 0.31666666666666665
# Venta global promedio de un juego de << Destination Software, Inc >> es: 0.07333333333333333
# Venta global promedio de un juego de << New >> es: 0.36
# Venta global promedio de un juego de << Brash Entertainment >> es: 0.12300000000000003
# Venta global promedio de un juego de << ITT Family Games >> es: 0.34
# Venta global promedio de un juego de << PopCap Games >> es: 0.10466666666666667
# Venta global promedio de un juego de << Home Entertainment Suppliers >> es: 0.11250000000000002
# Venta global promedio de un juego de << Ackkstudios >> es: 0.084
# Venta global promedio de un juego de << Starpath Corp. >> es: 0.33
# Venta global promedio de un juego de << P2 Games >> es: 0.13333333333333333
# Venta global promedio de un juego de << BPS >> es: 0.26
# Venta global promedio de un juego de << Gathering of Developers >> es: 0.13222222222222224
# Venta global promedio de un juego de << NewKidCo >> es: 0.14777777777777779
# Venta global promedio de un juego de << Storm City Games >> es: 0.08210526315789474
# Venta global promedio de un juego de << CokeM Interactive >> es: 0.31
# Venta global promedio de un juego de << CBS Electronics >> es: 0.31
# Venta global promedio de un juego de << Magix >> es: 0.175
# Venta global promedio de un juego de << Marvelous Interactive >> es: 0.07446428571428573
# Venta global promedio de un juego de << Kalypso Media >> es: 0.07500000000000001
# Venta global promedio de un juego de << Nihon Falcom Corporation >> es: 0.11
# Venta global promedio de un juego de << Wargaming.net >> es: 0.29
# Venta global promedio de un juego de << Angel Studios >> es: 0.14666666666666664
# Venta global promedio de un juego de << Arc System Works >> es: 0.05692307692307692
# Venta global promedio de un juego de << Playmates >> es: 0.28
# Venta global promedio de un juego de << SNK Playmore >> es: 0.05333333333333333
# Venta global promedio de un juego de << Hamster Corporation >> es: 0.15000000000000002
# Venta global promedio de un juego de << From Software >> es: 0.10866666666666669
# Venta global promedio de un juego de << Nippon Columbia >> es: 0.13571428571428573
# Venta global promedio de un juego de << Nichibutsu >> es: 0.28
# Venta global promedio de un juego de << Little Orbit >> es: 0.07846153846153844
# Venta global promedio de un juego de << Conspiracy Entertainment >> es: 0.060000000000000005
# Venta global promedio de un juego de << DTP Entertainment >> es: 0.08113636363636362
# Venta global promedio de un juego de << Hect >> es: 0.16666666666666666
# Venta global promedio de un juego de << Mumbo Jumbo >> es: 0.09666666666666668
# Venta global promedio de un juego de << Pacific Century Cyber Works >> es: 0.26
# Venta global promedio de un juego de << Indie Games >> es: 0.10666666666666667
# Venta global promedio de un juego de << Liquid Games >> es: 0.135
# Venta global promedio de un juego de << NEC >> es: 0.14333333333333334
# Venta global promedio de un juego de << Axela >> es: 0.25
# Venta global promedio de un juego de << ArtDink >> es: 0.0811111111111111
# Venta global promedio de un juego de << Sunsoft >> es: 0.095
# Venta global promedio de un juego de << Gust >> es: 0.08461538461538462
# Venta global promedio de un juego de << SNK >> es: 0.11772727272727272
# Venta global promedio de un juego de << NEC Interchannel >> es: 0.0975
# Venta global promedio de un juego de << FuRyu >> es: 0.04888888888888889
# Venta global promedio de un juego de << Xing Entertainment >> es: 0.24
# Venta global promedio de un juego de << ValuSoft >> es: 0.0975
# Venta global promedio de un juego de << Victor Interactive >> es: 0.0988888888888889
# Venta global promedio de un juego de << Detn8 Games >> es: 0.23
# Venta global promedio de un juego de << American Softworks >> es: 0.23
# Venta global promedio de un juego de << Nordcurrent >> es: 0.11800000000000002
# Venta global promedio de un juego de << Bomb >> es: 0.22
# Venta global promedio de un juego de << Falcom Corporation >> es: 0.075625
# Venta global promedio de un juego de << AQ Interactive >> es: 0.10600000000000001
# Venta global promedio de un juego de << CCP >> es: 0.22
# Venta global promedio de un juego de << Milestone S.r.l. >> es: 0.08
# Venta global promedio de un juego de << JoWood Productions >> es: 0.06772727272727273
# Venta global promedio de un juego de << Seta Corporation >> es: 0.10500000000000002
# Venta global promedio de un juego de << On Demand >> es: 0.21
# Venta global promedio de un juego de << NCS >> es: 0.13333333333333333
# Venta global promedio de un juego de << Aspyr >> es: 0.0775
# Venta global promedio de un juego de << Gremlin Interactive Ltd >> es: 0.1222222222222222
# Venta global promedio de un juego de << Agatsuma Entertainment >> es: 0.10333333333333335
# Venta global promedio de un juego de << Compile Heart >> es: 0.0685
# Venta global promedio de un juego de << Culture Brain >> es: 0.0675
# Venta global promedio de un juego de << Mad Catz >> es: 0.10000000000000002
# Venta global promedio de un juego de << Shogakukan >> es: 0.08800000000000001
# Venta global promedio de un juego de << Merscom LLC >> es: 0.2
# Venta global promedio de un juego de << Rebellion Developments >> es: 0.15000000000000002
# Venta global promedio de un juego de << Nippon Telenet >> es: 0.13
# Venta global promedio de un juego de << TDK Core >> es: 0.12400000000000003
# Venta global promedio de un juego de << bitComposer Games >> es: 0.082
# Venta global promedio de un juego de << Foreign Media Games >> es: 0.07
# Venta global promedio de un juego de << Astragon >> es: 0.10666666666666669
# Venta global promedio de un juego de << SSI >> es: 0.19
# Venta global promedio de un juego de << Kadokawa Games >> es: 0.03866666666666667
# Venta global promedio de un juego de << Idea Factory >> es: 0.03132812500000001
# Venta global promedio de un juego de << Performance Designed Products >> es: 0.18
# Venta global promedio de un juego de << Asylum Entertainment >> es: 0.09833333333333334
# Venta global promedio de un juego de << Core Design Ltd. >> es: 0.14500000000000002
# Venta global promedio de un juego de << PlayV >> es: 0.11
# Venta global promedio de un juego de << UFO Interactive >> es: 0.06
# Venta global promedio de un juego de << Idea Factory International >> es: 0.10166666666666668
# Venta global promedio de un juego de << Playlogic Game Factory >> es: 0.08571428571428573
# Venta global promedio de un juego de << Essential Games >> es: 0.07666666666666667
# Venta global promedio de un juego de << Adeline Software >> es: 0.17
# Venta global promedio de un juego de << Funcom >> es: 0.1
# Venta global promedio de un juego de << Panther Software >> es: 0.17
# Venta global promedio de un juego de << Blast! Entertainment Ltd >> es: 0.06333333333333334
# Venta global promedio de un juego de << Game Life >> es: 0.15000000000000002
# Venta global promedio de un juego de << DSI Games >> es: 0.05833333333333334
# Venta global promedio de un juego de << Avalon Interactive >> es: 0.08
# Venta global promedio de un juego de << Popcorn Arcade >> es: 0.049
# Venta global promedio de un juego de << Neko Entertainment >> es: 0.044285714285714296
# Venta global promedio de un juego de << Vir2L Studios >> es: 0.08666666666666667
# Venta global promedio de un juego de << Aques >> es: 0.16
# Venta global promedio de un juego de << Syscom >> es: 0.135
# Venta global promedio de un juego de << White Park Bay Software >> es: 0.16
# Venta global promedio de un juego de << System 3 >> es: 0.07333333333333335
# Venta global promedio de un juego de << Vatical Entertainment >> es: 0.11
# Venta global promedio de un juego de << Daedalic >> es: 0.09333333333333334
# Venta global promedio de un juego de << EA Games >> es: 0.15
# Venta global promedio de un juego de << Media Factory >> es: 0.14500000000000002
# Venta global promedio de un juego de << Vic Tokai >> es: 0.135
# Venta global promedio de un juego de << The Adventure Company >> es: 0.10200000000000001
# Venta global promedio de un juego de << Game Arts >> es: 0.14
# Venta global promedio de un juego de << Broccoli >> es: 0.04363636363636365
# Venta global promedio de un juego de << Acquire >> es: 0.08230769230769232
# Venta global promedio de un juego de << General Entertainment >> es: 0.14
# Venta global promedio de un juego de << Excalibur Publishing >> es: 0.07
# Venta global promedio de un juego de << Imadio >> es: 0.14
# Venta global promedio de un juego de << Swing! Entertainment >> es: 0.08
# Venta global promedio de un juego de << Sony Music Entertainment >> es: 0.14
# Venta global promedio de un juego de << Aqua Plus >> es: 0.054347826086956534
# Venta global promedio de un juego de << Paradox Interactive >> es: 0.03304347826086958
# Venta global promedio de un juego de << Hip Interactive >> es: 0.072
# Venta global promedio de un juego de << DreamCatcher Interactive >> es: 0.055882352941176466
# Venta global promedio de un juego de << Tripwire Interactive >> es: 0.14
# Venta global promedio de un juego de << Sting >> es: 0.07222222222222223
# Venta global promedio de un juego de << Yacht Club Games >> es: 0.10666666666666667
# Venta global promedio de un juego de << SCS Software >> es: 0.13
# Venta global promedio de un juego de << Bigben Interactive >> es: 0.06461538461538462
# Venta global promedio de un juego de << Havas Interactive >> es: 0.13
# Venta global promedio de un juego de << Slitherine Software >> es: 0.05333333333333334
# Venta global promedio de un juego de << Graffiti >> es: 0.06333333333333332
# Venta global promedio de un juego de << Funsta >> es: 0.05333333333333334
# Venta global promedio de un juego de << Telstar >> es: 0.09000000000000001
# Venta global promedio de un juego de << U.S. Gold >> es: 0.0825
# Venta global promedio de un juego de << DreamWorks Interactive >> es: 0.13
# Venta global promedio de un juego de << Data Design Interactive >> es: 0.09666666666666668
# Venta global promedio de un juego de << MTO >> es: 0.049999999999999996
# Venta global promedio de un juego de << DHM Interactive >> es: 0.06
# Venta global promedio de un juego de << FunSoft >> es: 0.12
# Venta global promedio de un juego de << SPS >> es: 0.12
# Venta global promedio de un juego de << Bohemia Interactive >> es: 0.12
# Venta global promedio de un juego de << Reef Entertainment >> es: 0.048571428571428585
# Venta global promedio de un juego de << Tru Blu Entertainment >> es: 0.035
# Venta global promedio de un juego de << Moss >> es: 0.065
# Venta global promedio de un juego de << T&E Soft >> es: 0.12
# Venta global promedio de un juego de << O-Games >> es: 0.06352941176470588
# Venta global promedio de un juego de << Aksys Games >> es: 0.055
# Venta global promedio de un juego de << NDA Productions >> es: 0.12
# Venta global promedio de un juego de << Data East >> es: 0.075
# Venta global promedio de un juego de << Time Warner Interactive >> es: 0.06999999999999999
# Venta global promedio de un juego de << Gainax Network Systems >> es: 0.08
# Venta global promedio de un juego de << Daito >> es: 0.057499999999999996
# Venta global promedio de un juego de << O3 Entertainment >> es: 0.07333333333333333
# Venta global promedio de un juego de << Gameloft >> es: 0.11
# Venta global promedio de un juego de << Xicat Interactive >> es: 0.05666666666666667
# Venta global promedio de un juego de << Simon & Schuster Interactive >> es: 0.11
# Venta global promedio de un juego de << Valcon Games >> es: 0.05625000000000001
# Venta global promedio de un juego de << PopTop Software >> es: 0.11
# Venta global promedio de un juego de << TOHO >> es: 0.11
# Venta global promedio de un juego de << HMH Interactive >> es: 0.07
# Venta global promedio de un juego de << 5pb >> es: 0.026721311475409838
# Venta global promedio de un juego de << Cave >> es: 0.033
# Venta global promedio de un juego de << CDV Software Entertainment >> es: 0.03333333333333333
# Venta global promedio de un juego de << Microids >> es: 0.04
# Venta global promedio de un juego de << PM Studios >> es: 0.1
# Venta global promedio de un juego de << Paon >> es: 0.041666666666666664
# Venta global promedio de un juego de << Micro Cabin >> es: 0.06666666666666667
# Venta global promedio de un juego de << GameTek >> es: 0.1
# Venta global promedio de un juego de << Benesse >> es: 0.055
# Venta global promedio de un juego de << Type-Moon >> es: 0.1
# Venta global promedio de un juego de << Enjoy Gaming ltd. >> es: 0.1
# Venta global promedio de un juego de << Asmik Corp >> es: 0.085
# Venta global promedio de un juego de << Interplay Productions >> es: 0.1
# Venta global promedio de un juego de << Asmik Ace Entertainment >> es: 0.07666666666666667
# Venta global promedio de un juego de << inXile Entertainment >> es: 0.1
# Venta global promedio de un juego de << Image Epoch >> es: 0.1
# Venta global promedio de un juego de << Phantom EFX >> es: 0.09
# Venta global promedio de un juego de << Evolved Games >> es: 0.04
# Venta global promedio de un juego de << responDESIGN >> es: 0.065
# Venta global promedio de un juego de << Culture Publishers >> es: 0.09
# Venta global promedio de un juego de << Griffin International >> es: 0.09
# Venta global promedio de un juego de << Hackberry >> es: 0.04428571428571428
# Venta global promedio de un juego de << Hearty Robin >> es: 0.09
# Venta global promedio de un juego de << Nippon Amuse >> es: 0.09
# Venta global promedio de un juego de << Origin Systems >> es: 0.09
# Venta global promedio de un juego de << Seventh Chord >> es: 0.08
# Venta global promedio de un juego de << Mitsui >> es: 0.08
# Venta global promedio de un juego de << Milestone >> es: 0.08
# Venta global promedio de un juego de << Abylight >> es: 0.08
# Venta global promedio de un juego de << Flight-Plan >> es: 0.06
# Venta global promedio de un juego de << Glams >> es: 0.08
# Venta global promedio de un juego de << Locus >> es: 0.07
# Venta global promedio de un juego de << Warp >> es: 0.07
# Venta global promedio de un juego de << Daedalic Entertainment >> es: 0.04666666666666667
# Venta global promedio de un juego de << Alternative Software >> es: 0.03333333333333333
# Venta global promedio de un juego de << Myelin Media >> es: 0.043333333333333335
# Venta global promedio de un juego de << Mercury Games >> es: 0.0525
# Venta global promedio de un juego de << Irem Software Engineering >> es: 0.03833333333333334
# Venta global promedio de un juego de << Sunrise Interactive >> es: 0.042499999999999996
# Venta global promedio de un juego de << Elite >> es: 0.07
# Venta global promedio de un juego de << Evolution Games >> es: 0.07
# Venta global promedio de un juego de << Tivola >> es: 0.05666666666666667
# Venta global promedio de un juego de << Global A Entertainment >> es: 0.037500000000000006
# Venta global promedio de un juego de << Edia >> es: 0.045000000000000005
# Venta global promedio de un juego de << Athena >> es: 0.045000000000000005
# Venta global promedio de un juego de << Aria >> es: 0.07
# Venta global promedio de un juego de << Gamecock >> es: 0.049999999999999996
# Venta global promedio de un juego de << Tommo >> es: 0.041999999999999996
# Venta global promedio de un juego de << Altron >> es: 0.07
# Venta global promedio de un juego de << Happinet >> es: 0.036000000000000004
# Venta global promedio de un juego de << iWin >> es: 0.06
# Venta global promedio de un juego de << Media Works >> es: 0.036
# Venta global promedio de un juego de << Fortyfive >> es: 0.06
# Venta global promedio de un juego de << Revolution Software >> es: 0.034999999999999996
# Venta global promedio de un juego de << Imax >> es: 0.06
# Venta global promedio de un juego de << Crimson Cow >> es: 0.04
# Venta global promedio de un juego de << 10TACLE Studios >> es: 0.03666666666666667
# Venta global promedio de un juego de << Groove Games >> es: 0.045
# Venta global promedio de un juego de << Pack-In-Video >> es: 0.055
# Venta global promedio de un juego de << Insomniac Games >> es: 0.04
# Venta global promedio de un juego de << Ascaron Entertainment GmbH >> es: 0.03666666666666667
# Venta global promedio de un juego de << Asgard >> es: 0.03125
# Venta global promedio de un juego de << Ecole >> es: 0.06
# Venta global promedio de un juego de << Yumedia >> es: 0.06
# Venta global promedio de un juego de << Phenomedia >> es: 0.0475
# Venta global promedio de un juego de << HAL Laboratory >> es: 0.06
# Venta global promedio de un juego de << Grand Prix Games >> es: 0.06
# Venta global promedio de un juego de << DigiCube >> es: 0.06
# Venta global promedio de un juego de << Creative Core >> es: 0.03333333333333333
# Venta global promedio de un juego de << Kaga Create >> es: 0.023333333333333334
# Venta global promedio de un juego de << WayForward Technologies >> es: 0.05
# Venta global promedio de un juego de << LSP Games >> es: 0.03
# Venta global promedio de un juego de << ASCII Media Works >> es: 0.030000000000000002
# Venta global promedio de un juego de << Coconuts Japan >> es: 0.035
# Venta global promedio de un juego de << Arika >> es: 0.030000000000000002
# Venta global promedio de un juego de << Ertain >> es: 0.05
# Venta global promedio de un juego de << Marvel Entertainment >> es: 0.05
# Venta global promedio de un juego de << Prototype >> es: 0.02259259259259259
# Venta global promedio de un juego de << Phantagram >> es: 0.05
# Venta global promedio de un juego de << 1C Company >> es: 0.03333333333333333
# Venta global promedio de un juego de << The Learning Company >> es: 0.05
# Venta global promedio de un juego de << TechnoSoft >> es: 0.05
# Venta global promedio de un juego de << Vap >> es: 0.05
# Venta global promedio de un juego de << Misawa >> es: 0.035
# Venta global promedio de un juego de << Tradewest >> es: 0.03666666666666667
# Venta global promedio de un juego de << Team17 Software >> es: 0.05
# Venta global promedio de un juego de << Yeti >> es: 0.02181818181818182
# Venta global promedio de un juego de << Pow >> es: 0.05
# Venta global promedio de un juego de << Navarre Corp >> es: 0.05
# Venta global promedio de un juego de << MediaQuest >> es: 0.05
# Venta global promedio de un juego de << Max Five >> es: 0.05
# Venta global promedio de un juego de << Comfort >> es: 0.025000000000000005
# Venta global promedio de un juego de << Monte Christo Multimedia >> es: 0.05
# Venta global promedio de un juego de << Pony Canyon >> es: 0.05
# Venta global promedio de un juego de << Riverhillsoft >> es: 0.04
# Venta global promedio de un juego de << Summitsoft >> es: 0.04
# Venta global promedio de un juego de << Milestone S.r.l >> es: 0.025
# Venta global promedio de un juego de << Playmore >> es: 0.04
# Venta global promedio de un juego de << MLB.com >> es: 0.04
# Venta global promedio de un juego de << Kool Kizz >> es: 0.04
# Venta global promedio de un juego de << Flashpoint Games >> es: 0.04
# Venta global promedio de un juego de << 49Games >> es: 0.04
# Venta global promedio de un juego de << Legacy Interactive >> es: 0.04
# Venta global promedio de un juego de << Alawar Entertainment >> es: 0.025
# Venta global promedio de un juego de << CyberFront >> es: 0.019285714285714288
# Venta global promedio de un juego de << Cloud Imperium Games Corporation >> es: 0.04
# Venta global promedio de un juego de << Societa >> es: 0.04
# Venta global promedio de un juego de << Virtual Play Games >> es: 0.03
# Venta global promedio de un juego de << Interchannel >> es: 0.025
# Venta global promedio de un juego de << Sonnet >> es: 0.03
# Venta global promedio de un juego de << Experience Inc. >> es: 0.02
# Venta global promedio de un juego de << Zenrin >> es: 0.03
# Venta global promedio de un juego de << Iceberg Interactive >> es: 0.02666666666666667
# Venta global promedio de un juego de << Ivolgamus >> es: 0.04
# Venta global promedio de un juego de << 2D Boy >> es: 0.04
# Venta global promedio de un juego de << MC2 Entertainment >> es: 0.02666666666666667
# Venta global promedio de un juego de << Kando Games >> es: 0.03
# Venta global promedio de un juego de << Just Flight >> es: 0.03
# Venta global promedio de un juego de << Office Create >> es: 0.03
# Venta global promedio de un juego de << Mamba Games >> es: 0.025
# Venta global promedio de un juego de << Fields >> es: 0.03
# Venta global promedio de un juego de << Princess Soft >> es: 0.023333333333333334
# Venta global promedio de un juego de << Maximum Family Games >> es: 0.03
# Venta global promedio de un juego de << Berkeley >> es: 0.03
# Venta global promedio de un juego de << Fuji >> es: 0.03
# Venta global promedio de un juego de << Dusenberry Martin Racing >> es: 0.025
# Venta global promedio de un juego de << imageepoch Inc. >> es: 0.02
# Venta global promedio de un juego de << Big Fish Games >> es: 0.025
# Venta global promedio de un juego de << Her Interactive >> es: 0.03
# Venta global promedio de un juego de << Kamui >> es: 0.03
# Venta global promedio de un juego de << ASK >> es: 0.03
# Venta global promedio de un juego de << TopWare Interactive >> es: 0.02
# Venta global promedio de un juego de << Headup Games >> es: 0.03
# Venta global promedio de un juego de << KSS >> es: 0.03
# Venta global promedio de un juego de << Cygames >> es: 0.03
# Venta global promedio de un juego de << KID >> es: 0.02
# Venta global promedio de un juego de << Quinrose >> es: 0.01571428571428572
# Venta global promedio de un juego de << Sunflowers >> es: 0.03
# Venta global promedio de un juego de << dramatic create >> es: 0.022
# Venta global promedio de un juego de << TGL >> es: 0.024999999999999998
# Venta global promedio de un juego de << Encore >> es: 0.0175
# Venta global promedio de un juego de << Extreme Entertainment Group >> es: 0.03
# Venta global promedio de un juego de << Intergrow >> es: 0.03
# Venta global promedio de un juego de << G.Rev >> es: 0.02
# Venta global promedio de un juego de << Sweets >> es: 0.025
# Venta global promedio de un juego de << Kokopeli Digital Studios >> es: 0.03
# Venta global promedio de un juego de << Number None >> es: 0.03
# Venta global promedio de un juego de << Nexon >> es: 0.03
# Venta global promedio de un juego de << id Software >> es: 0.03
# Venta global promedio de un juego de << BushiRoad >> es: 0.03
# Venta global promedio de un juego de << Tryfirst >> es: 0.03
# Venta global promedio de un juego de << Strategy First >> es: 0.03
# Venta global promedio de un juego de << 7G//AMES >> es: 0.02
# Venta global promedio de un juego de << GN Software >> es: 0.016666666666666666
# Venta global promedio de un juego de << Yuke's >> es: 0.02666666666666667
# Venta global promedio de un juego de << Easy Interactive >> es: 0.025
# Venta global promedio de un juego de << Licensed 4U >> es: 0.023333333333333334
# Venta global promedio de un juego de << FuRyu Corporation >> es: 0.03
# Venta global promedio de un juego de << Lexicon Entertainment >> es: 0.025
# Venta global promedio de un juego de << Paon Corporation >> es: 0.03
# Venta global promedio de un juego de << Kids Station >> es: 0.03
# Venta global promedio de un juego de << GOA >> es: 0.02
# Venta global promedio de un juego de << Graphsim Entertainment >> es: 0.02
# Venta global promedio de un juego de << King Records >> es: 0.02
# Venta global promedio de un juego de << Introversion Software >> es: 0.02
# Venta global promedio de un juego de << Minato Station >> es: 0.016666666666666666
# Venta global promedio de un juego de << Devolver Digital >> es: 0.02
# Venta global promedio de un juego de << Blue Byte >> es: 0.015
# Venta global promedio de un juego de << Gaga >> es: 0.02
# Venta global promedio de un juego de << Yamasa Entertainment >> es: 0.02
# Venta global promedio de un juego de << Plenty >> es: 0.02
# Venta global promedio de un juego de << Views >> es: 0.015
# Venta global promedio de un juego de << fonfun >> es: 0.02
# Venta global promedio de un juego de << NetRevo >> es: 0.015
# Venta global promedio de un juego de << Codemasters Online >> es: 0.02
# Venta global promedio de un juego de << Quintet >> es: 0.02
# Venta global promedio de un juego de << Phoenix Games >> es: 0.02
# Venta global promedio de un juego de << Dorart >> es: 0.015
# Venta global promedio de un juego de << Marvelous Games >> es: 0.02
# Venta global promedio de un juego de << Focus Multimedia >> es: 0.016666666666666666
# Venta global promedio de un juego de << Imageworks >> es: 0.02
# Venta global promedio de un juego de << Karin Entertainment >> es: 0.02
# Venta global promedio de un juego de << Aerosoft >> es: 0.015
# Venta global promedio de un juego de << Technos Japan Corporation >> es: 0.02
# Venta global promedio de un juego de << Gakken >> es: 0.02
# Venta global promedio de un juego de << Mirai Shounen >> es: 0.02
# Venta global promedio de un juego de << Datam Polystar >> es: 0.015
# Venta global promedio de un juego de << Saurus >> es: 0.02
# Venta global promedio de un juego de << HuneX >> es: 0.015
# Venta global promedio de un juego de << Revolution (Japan) >> es: 0.02
# Venta global promedio de un juego de << Giza10 >> es: 0.02
# Venta global promedio de un juego de << Visco >> es: 0.02
# Venta global promedio de un juego de << Alvion >> es: 0.02
# Venta global promedio de un juego de << Mycom >> es: 0.02
# Venta global promedio de un juego de << Giga >> es: 0.02
# Venta global promedio de un juego de << Warashi >> es: 0.02
# Venta global promedio de un juego de << System Soft >> es: 0.0125
# Venta global promedio de un juego de << Sold Out >> es: 0.02
# Venta global promedio de un juego de << Lighthouse Interactive >> es: 0.02
# Venta global promedio de un juego de << Masque Publishing >> es: 0.02
# Venta global promedio de un juego de << RED Entertainment >> es: 0.02
# Venta global promedio de un juego de << Michaelsoft >> es: 0.01
# Venta global promedio de un juego de << Media Entertainment >> es: 0.01
# Venta global promedio de un juego de << New World Computing >> es: 0.01
# Venta global promedio de un juego de << Genterprise >> es: 0.01
# Venta global promedio de un juego de << Interworks Unlimited, Inc. >> es: 0.01
# Venta global promedio de un juego de << Boost On >> es: 0.01
# Venta global promedio de un juego de << Stainless Games >> es: 0.01
# Venta global promedio de un juego de << EON Digital Entertainment >> es: 0.01
# Venta global promedio de un juego de << Epic Games >> es: 0.01
# Venta global promedio de un juego de << Naxat Soft >> es: 0.01
# Venta global promedio de un juego de << Ascaron Entertainment >> es: 0.01
# Venta global promedio de un juego de << Piacci >> es: 0.01
# Venta global promedio de un juego de << Nitroplus >> es: 0.01
# Venta global promedio de un juego de << Paradox Development >> es: 0.01
# Venta global promedio de un juego de << Otomate >> es: 0.01
# Venta global promedio de un juego de << Ongakukan >> es: 0.01
# Venta global promedio de un juego de << Commseed >> es: 0.01
# Venta global promedio de un juego de << Inti Creates >> es: 0.01
# Venta global promedio de un juego de << Takuyo >> es: 0.01
# Venta global promedio de un juego de << Interchannel-Holon >> es: 0.01
# Venta global promedio de un juego de << Rain Games >> es: 0.01
# Venta global promedio de un juego de << UIG Entertainment >> es: 0.01

# %% [markdown]
# Generemos un array con los renglones que contengan un dato (string) en específico dentro de una columna (columna Name) también en especifica.

# %%
#df_overall.reset_index(inplace=True)
i = 0
ll =[]
for name in df_overall["Name"][0:len(df_overall["Name"])]:
    if( "Mario" in name): #<--- Incruste nombre a buscar
        l = []
        for x in df_overall.loc[i]:
            l.append(x)
        ll.append(l)
    i += 1

# %%
ll
# Out:
# [[1, 1, 'Super Mario Bros.', 1985.0, 'Nintendo', 'NES', 40.24],
#  [2, 2, 'Mario Kart Wii', 2008.0, 'Nintendo', 'Wii', 35.82],
#  [6, 6, 'New Super Mario Bros.', 2006.0, 'Nintendo', 'DS', 30.01],
#  [8, 8, 'New Super Mario Bros. Wii', 2009.0, 'Nintendo', 'Wii', 28.62],
#  [11, 11, 'Mario Kart DS', 2005.0, 'Nintendo', 'DS', 23.42],
#  [18, 18, 'Super Mario World', 1990.0, 'Nintendo', 'SNES', 20.61],
#  [21, 21, 'Super Mario Land', 1989.0, 'Nintendo', 'GB', 18.14],
#  [22, 22, 'Super Mario Bros. 3', 1988.0, 'Nintendo', 'NES', 17.28],
#  [42, 42, 'Mario Kart 7', 2011.0, 'Nintendo', '3DS', 12.21],
#  [46, 46, 'Super Mario 64', 1996.0, 'Nintendo', 'N64', 11.89],
#  [48, 48, 'Super Mario Galaxy', 2007.0, 'Nintendo', 'Wii', 11.52],
#  [50,
#   50,
#   'Super Mario Land 2: 6 Golden Coins',
#   1992.0,
#   'Nintendo',
#   'GB',
#   11.18],
#  [53, 53, 'Super Mario 3D Land', 2011.0, 'Nintendo', '3DS', 10.79],
#  [57, 57, 'Super Mario All-Stars', 1993.0, 'Nintendo', 'SNES', 10.55],
#  [59, 59, 'Super Mario 64', 2004.0, 'Nintendo', 'DS', 10.42],
#  [63, 63, 'Mario Kart 64', 1996.0, 'Nintendo', 'N64', 9.87],
#  [64, 64, 'New Super Mario Bros. 2', 2012.0, 'Nintendo', '3DS', 9.82],
#  [74, 74, 'Mario Party DS', 2007.0, 'Nintendo', 'DS', 9.02],
#  [76, 76, 'Super Mario Kart', 1992.0, 'Nintendo', 'SNES', 8.76],
#  [80, 80, 'Mario Party 8', 2007.0, 'Nintendo', 'Wii', 8.42],
#  [85, 85, 'Mario & Sonic at the Olympic Games', 2007.0, 'Sega', 'Wii', 8.06],
#  [91, 91, 'Super Mario Galaxy 2', 2010.0, 'Nintendo', 'Wii', 7.69],
#  [96, 96, 'Super Mario Bros. 2', 1988.0, 'Nintendo', 'NES', 7.46],
#  [108, 108, 'Mario Kart 8', 2014.0, 'Nintendo', 'WiiU', 6.96],
#  [110, 110, 'Mario Kart: Double Dash!!', 2003.0, 'Nintendo', 'GC', 6.95],
#  [135, 135, 'Super Mario Sunshine', 2002.0, 'Nintendo', 'GC', 6.31],
#  [162, 162, 'Super Mario Advance', 2001.0, 'Nintendo', 'GBA', 5.49],
#  [163, 163, 'Mario Kart: Super Circuit', 2001.0, 'Nintendo', 'GBA', 5.47],
#  [164, 164, 'Super Mario World', 2001.0, 'Nintendo', 'GBA', 5.46],
#  [170, 170, 'Dr. Mario', 1989.0, 'Nintendo', 'GB', 5.34],
#  [181, 182, 'Super Mario Bros. 3', 2003.0, 'Nintendo', 'GBA', 5.2],
#  [182, 183, 'New Super Mario Bros. U', 2012.0, 'Nintendo', 'WiiU', 5.19],
#  [183, 184, 'Super Mario Land 3: Wario Land', 1994.0, 'Nintendo', 'GB', 5.19],
#  [188, 189, 'Mario & Sonic at the Olympic Games', 2008.0, 'Sega', 'DS', 5.14],
#  [199, 200, 'Super Mario Bros.', 1999.0, 'Nintendo', 'GB', 5.07],
#  [214, 215, 'Dr. Mario', 1990.0, 'Nintendo', 'NES', 4.85],
#  [232,
#   233,
#   'Mario & Sonic at the Olympic Winter Games',
#   2009.0,
#   'Sega',
#   'Wii',
#   4.58],
#  [260, 261, 'Super Mario 3D World', 2013.0, 'Nintendo', 'WiiU', 4.25],
#  [281,
#   282,
#   "Super Mario World 2: Yoshi's Island",
#   1995.0,
#   'Nintendo',
#   'SNES',
#   4.12],
#  [318,
#   319,
#   "Mario & Luigi: Bowser's Inside Story",
#   2009.0,
#   'Nintendo',
#   'DS',
#   3.83],
#  [322,
#   323,
#   'Mario & Sonic at the London 2012 Olympic Games',
#   2011.0,
#   'Sega',
#   'Wii',
#   3.78],
#  [328, 329, 'Super Paper Mario', 2007.0, 'Nintendo', 'Wii', 3.76],
#  [369,
#   370,
#   'Mario & Sonic at the Olympic Winter Games',
#   2009.0,
#   'Sega',
#   'DS',
#   3.52],
#  [403, 405, 'Mario Party 9', 2012.0, 'Nintendo', 'Wii', 3.32],
#  [427, 429, 'Super Mario Maker', 2015.0, 'Nintendo', 'WiiU', 3.18],
#  [488,
#   492,
#   "Super Mario World 2: Yoshi's Island",
#   2002.0,
#   'Nintendo',
#   'GBA',
#   2.91],
#  [541, 545, 'Mario Paint', 1992.0, 'Nintendo', 'SNES', 2.75],
#  [550, 554, 'Mario Party', 1998.0, 'Nintendo', 'N64', 2.7],
#  [554,
#   558,
#   'Mario vs. Donkey Kong: Mini-Land Mayhem!',
#   2010.0,
#   'Nintendo',
#   'DS',
#   2.69],
#  [569,
#   573,
#   'Super Mario Bros.: The Lost Levels',
#   1986.0,
#   'Nintendo',
#   'NES',
#   2.65],
#  [577, 581, 'Mario Strikers Charged', 2007.0, 'Nintendo', 'Wii', 2.62],
#  [583,
#   587,
#   'Super Mario All-Stars: Limited Edition',
#   2010.0,
#   'Nintendo',
#   'Wii',
#   2.6],
#  [610, 615, 'Mario Party 2', 1999.0, 'Nintendo', 'N64', 2.5],
#  [620, 626, 'Mario Party 4', 2002.0, 'Nintendo', 'GC', 2.47],
#  [675, 683, 'Mario Tennis', 2000.0, 'Nintendo', 'N64', 2.32],
#  [692, 700, 'Mario Bros.', 1983.0, 'Nintendo', 'NES', 2.28],
#  [697, 705, 'Paper Mario: Sticker Star', 2012.0, 'Nintendo', '3DS', 2.27],
#  [707,
#   716,
#   'Paper Mario: The Thousand-Year Door',
#   2004.0,
#   'Nintendo',
#   'GC',
#   2.25],
#  [742, 751, 'Mario & Luigi: Superstar Saga', 2003.0, 'Nintendo', 'GBA', 2.17],
#  [753,
#   762,
#   'Super Mario RPG: Legend of the Seven Stars',
#   1996.0,
#   'Nintendo',
#   'SNES',
#   2.14],
#  [772, 781, 'Mario Sports Mix', 2010.0, 'Nintendo', 'Wii', 2.11],
#  [793, 803, 'Mario Party 5', 2003.0, 'Nintendo', 'GC', 2.08],
#  [810, 820, 'Mario & Luigi: Dream Team', 2013.0, 'Nintendo', '3DS', 2.06],
#  [882, 892, 'Mario Super Sluggers', 2008.0, 'Nintendo', 'Wii', 1.93],
#  [892, 902, 'Mario Party 3', 2000.0, 'Nintendo', 'N64', 1.91],
#  [924, 934, 'Mario Party: Island Tour', 2013.0, 'Nintendo', '3DS', 1.85],
#  [1097, 1107, 'Mario Party 6', 2004.0, 'Nintendo', 'GC', 1.65],
#  [1124, 1136, 'Mario Hoops 3 on 3', 2006.0, 'Nintendo', 'DS', 1.62],
#  [1132, 1144, 'Super Mario Strikers', 2005.0, 'Nintendo', 'GC', 1.61],
#  [1151, 1163, 'Mario Bros.', 1982.0, 'Atari', '2600', 1.59],
#  [1171, 1183, 'Mario Party 7', 2005.0, 'Nintendo', 'GC', 1.57],
#  [1195, 1207, 'Mario Party 10', 2015.0, 'Nintendo', 'WiiU', 1.55],
#  [1213, 1225, 'Mario Golf: Toadstool Tour', 2003.0, 'Nintendo', 'GC', 1.53],
#  [1263,
#   1275,
#   'New Play Control! Mario Power Tennis',
#   2009.0,
#   'Nintendo',
#   'Wii',
#   1.48],
#  [1276, 1288, 'Mario Golf', 1999.0, 'Nintendo', 'N64', 1.47],
#  [1295, 1308, 'Mario Superstar Baseball', 2005.0, 'Nintendo', 'GC', 1.46],
#  [1338,
#   1351,
#   'Classic NES Series: Super Mario Bros.',
#   2004.0,
#   'Nintendo',
#   'GBA',
#   1.43],
#  [1388, 1401, 'Paper Mario', 2000.0, 'Nintendo', 'N64', 1.38],
#  [1442,
#   1456,
#   'Mario & Luigi: Partners in Time',
#   2005.0,
#   'Nintendo',
#   'DS',
#   1.34],
#  [1617, 1634, 'Mario Power Tennis', 2004.0, 'Nintendo', 'GC', 1.22],
#  [1662,
#   1681,
#   'Mario vs. Donkey Kong 2: March of the Minis',
#   2006.0,
#   'Nintendo',
#   'DS',
#   1.2],
#  [1673,
#   1692,
#   'Mario & Sonic at the London 2012 Olympic Games',
#   2012.0,
#   'Sega',
#   '3DS',
#   1.19],
#  [1690, 1710, 'Mario Tennis', 2000.0, 'Nintendo', 'GB', 1.18],
#  [1718, 1738, 'Mario vs. Donkey Kong', 2004.0, 'Nintendo', 'GBA', 1.17],
#  [2085, 2109, 'Mario Party Advance', 2005.0, 'Nintendo', 'GBA', 0.98],
#  [2175, 2204, 'Mario Tennis Open', 2012.0, 'Nintendo', '3DS', 0.94],
#  [2552,
#   2590,
#   'Mario & Sonic at the Sochi 2014 Olympic Winter Games',
#   2013.0,
#   'Nintendo',
#   'WiiU',
#   0.8],
#  [2733, 2771, 'Mario & Luigi: Paper Jam', 2015.0, 'Nintendo', '3DS', 0.74],
#  [2912, 2954, 'Mario Pinball Land', 2004.0, 'Nintendo', 'GBA', 0.69],
#  [3222, 3271, "Mario's Picross", 1995.0, 'Nintendo', 'GB', 0.62],
#  [3515,
#   3568,
#   'Classic NES Series: Dr. Mario',
#   2004.0,
#   'Nintendo',
#   'GBA',
#   0.56],
#  [3766, 3822, 'Mario Tennis: Power Tour', 2005.0, 'Nintendo', 'GBA', 0.52],
#  [3983, 4041, 'Mario & Wario', 1993.0, 'Nintendo', 'SNES', 0.49],
#  [4033, 4091, 'Mario Golf: World Tour', 2014.0, 'Nintendo', '3DS', 0.48],
#  [4160,
#   4221,
#   'Dance Dance Revolution: Mario Mix',
#   2005.0,
#   'Nintendo',
#   'GC',
#   0.47],
#  [4199,
#   4261,
#   'Mario & Sonic at the Rio 2016 Olympic Games',
#   2016.0,
#   'Nintendo',
#   '3DS',
#   0.46],
#  [4237,
#   4299,
#   'Puzzle & Dragons Z + Super Mario Bros. Edition',
#   2015.0,
#   'Nintendo',
#   '3DS',
#   0.46],
#  [4335, 4400, 'Mario Tennis Ultra Smash', 2015.0, 'Nintendo', 'WiiU', 0.45],
#  [4339, 4404, 'Mario Golf: Advance Tour', 2004.0, 'Nintendo', 'GBA', 0.45],
#  [4519,
#   4588,
#   'Famicom Mini: Super Mario Bros. 2',
#   2004.0,
#   'Nintendo',
#   'GBA',
#   0.42],
#  [4554, 4623, 'Dr. Mario 64', 2001.0, 'Nintendo', 'N64', 0.42],
#  [4694, 4765, 'Mario no Super Picross', 1995.0, 'Nintendo', 'SNES', 0.41],
#  [5482, 5567, 'Dr. Mario / Puzzle League', 2005.0, 'Nintendo', 'GBA', 0.33],
#  [5626, 5716, 'Mario Golf', 1999.0, 'Nintendo', 'GB', 0.31],
#  [6477,
#   6588,
#   'Mario & Sonic at the Rio 2016 Olympic Games',
#   2016.0,
#   'Nintendo',
#   'WiiU',
#   0.26],
#  [11084, 11282, 'Famicom Mini: Mario Bros.', 2004.0, 'Nintendo', 'GBA', 0.08],
#  [11910, 12123, 'Mario Tennis', 2010.0, 'Nintendo', 'Wii', 0.07],
#  [12153,
#   12373,
#   'Mario vs. Donkey Kong: Tipping Stars',
#   2015.0,
#   'Nintendo',
#   '3DS',
#   0.06],
#  [12543,
#   12770,
#   'Dance Dance Revolution: Mario Mix (JP sales)',
#   2005.0,
#   'Nintendo',
#   'GC',
#   0.06],
#  [13038,
#   13273,
#   'Detective Conan: Marionette Symphony',
#   2013.0,
#   'Namco Bandai Games',
#   '3DS',
#   0.05],
#  [16057,
#   16357,
#   'Mario vs. Donkey Kong: Tipping Stars',
#   2015.0,
#   'Nintendo',
#   'WiiU',
#   0.01],
#  [16237,
#   16542,
#   'Mario & Luigi: Paper Jam & Mario Kart 7 Double Pack',
#   2015.0,
#   'Nintendo',
#   '3DS',
#   0.01]]

# %%
stringPublishers = ""
for name in df_overall["Publisher"][0:len(df_overall["Publisher"])]:
    stringPublishers += name + " "

wordcloud = WordCloud().generate(stringPublishers)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
df_overall["Publisher"].mode()
# Out:
# 0    Electronic Arts
# dtype: object

# %%
def save_global_sale_average(publisher, dicc):
    booleans = df_overall['Publisher'] == publisher
    df_publisher = df_overall[booleans]
    dicc[publisher] = df_publisher['Global_Sales'].sum() / len(df_publisher)

# %%
dicc = {}
for publisher in publishers:
     save_global_sale_average(publisher,dicc)

# %%
#dicc
wordcloud = WordCloud().generate_from_frequencies(dicc)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
#pub = df.groupby("Publisher")
pub = df.head(100).groupby("Publisher")
plt.figure(figsize=(15,10))
pub.size().sort_values(ascending=False).plot.bar()
plt.xticks(rotation=50)
plt.xlabel("Publishers")
plt.ylabel("Numero de Juegos")
plt.show()
